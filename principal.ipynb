# %% [markdown]
# # APS Parte 1
#
# Os objetivos de desenvolvimento sustentável da ONU, são um conjuto de 17 objetivos que devem ser atendidos para a melhora da qualidade de vida em nível global. Nesse contexto escolhemos o objetivo 4: Educação de qualidade, que segundo o site da Nações Unidas se baseia em ''garantir o acesso à educação inclusiva, de qualidade e equitativa, e promover oportunidades de aprendizagem ao longo da vida para todos'', ou seja esse objetivo está relacionado com a acessibilade de educação de qualidade à toda população global.
#
# Nossa equipe decidiu esse objetivo devido a sua relevância, já que é crucial garantir uma educação de qualidade caso a sociedade queira evoluir.
# Para a análise e construção do gráfico, escolhemos o indicador "Gastos totais do governo com educação (% do PIB)", uma vez que a procentagem do Produto Interno Bruto (PIB) evidencia a preocupação de determinado país com o sistema educacional, já que revela os investimentos nessa área em comparação ao PIB total do país, sem beneficiar paises que possuem um PIB superior com relação aos outros que possuem tal índice menor.
# Os países escolhidos como referência para este estudo foram: Noruega, Brasil e Afeganistão.
#
#
#
# * Objetivo: https://brasil.un.org/pt-br/sdgs/4
# * Indicador: https://data.worldbank.org/indicator/SE.XPD.TOTL.GD.ZS

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('dados/API_SE.XPD.TOTL.GD.ZS_DS2_en_csv_v2_4411877/API_SE.XPD.TOTL.GD.ZS_DS2_en_csv_v2_4411877.csv', skiprows=4,decimal='.',encoding='latin')


df_bra = df.iloc[29]
df_afe = df.iloc[2]
df_nor = df.iloc[177]

anos = []
for ano in range(2003, 2020):
    anos.append(str(ano))



plt.figure(figsize=(12,8))
plt.plot(df_nor[anos])
plt.plot(df_bra[anos], color='green')
plt.plot(df_afe[anos])
plt.xticks(range(0,len(anos),2), rotation=45)
plt.title('O quanto alguns Países investem de seu PIB em educação (2003-2019)', fontsize=20, y=1.05)
plt.ylabel('Porcentagem do PIB investida em educação (%)', fontsize=15)
plt.xlabel('Anos', fontsize=15)
plt.legend(['Noruega','Brasil', 'Afeganistão'])

plt.show()

# %% [markdown]
# # APS Parte 3
#
# <h1>Exercício 1</h1>
#
# ## Blocos Escolhidos
#
# União Europeia e OTAN (Organização do Tratado do Atlântico Norte)
#
# ## Critérios de criação dos blocos
#
# ### União Europeia
# Este bloco econômico foi criado em 1992 a fim de establecer uma cooperação econômica política entre os países europeus. O contexto da criação de tal bloco econômico foi durante o período da Guerra Fria, época marcada pela grande bipolarização mundial entre americanos e soviéticos. A proposta da União Europeia (antes chamada de CEE (Comunidade Econômica Europeia)) era incentivar a cooperação econômica de seus membros, estabelecendo uma relação de mercado comum entre os países.
#
# Dentre as aberturas providas pelo bloco, destacam-se a criação de uma moeda única (Euro) e a livre circulação de pessoas pelos países membros de tal bloco.
#
#
# ### OTAN
# A OTAN (Organização do Tratado do Atlântico Norte) foi criada em 1949, com o objetivo de estabelecer uma cooperação militar entre os países membros. A criação da OTAN foi motivada pela Guerra Fria, época marcada pela grande bipolarização mundial entre americanos e soviéticos. A proposta deste bloco era incentivar a cooperação militar de seus membros, estabelecendo uma relação de defesa comum entre os países.
#
# Dentre as aberturas providas pelo bloco, destacam-se a criação de uma força militar comum e a livre circulação de pessoas pelos países membros de tal bloco.

# %%
df = pd.read_csv('dados/aps3/API_SE.XPD.TOTL.GB.ZS_DS2_en_csv_v2_4661202.csv' , skiprows=4, decimal='.', encoding='latin')
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  21.877630  19.617979  23.201380
# 1   NaN   NaN   NaN   NaN   NaN  ...  17.243259  18.097099  16.962910
# ...

# %%
paises_eu = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden']
paises_otan = ['Albania', 'Algeria', 'Andorra', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Canada', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kazakhstan', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macedonia', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom', 'United States']

# Excluindo os países repetidos
for pais in paises_eu:
    if pais in paises_otan:
        paises_otan.remove(pais)

# Criando um DataFrame com os países da OTAN, UE e um total
df_ue = df[df['Country Name'].isin(paises_eu)]
df_otan = df[df['Country Name'].isin(paises_otan)]
df_conjunto = pd.concat([df_ue, df_otan])

# Selecionando os anos indesejados do DataFrame
anos=[]
for ano in range(1960, 2005):
    anos.append(str(ano))


# Excluíndo colunas indesejadas
df_ue = df_ue.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 66'])
df_ue = df_ue.drop(anos, axis=1)
df_ue['media'] = df_ue.mean(axis=1)

df_otan = df_otan.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 66'])
df_otan = df_otan.drop(anos, axis=1)
df_otan['media'] = df_otan.mean(axis=1)
df_otan

df_conjunto = df_conjunto.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 66'])
df_conjunto = df_conjunto.drop(anos, axis=1)
df_conjunto['media'] = df_conjunto.mean(axis=1)

# Calculando a média do conjunto de países da OTAN e UE
media = df_conjunto['media'].mean()
print(media)
# Out:
# 12.001642776320027
# C:\Users\leona\AppData\Local\Temp\ipykernel_20832\1969328386.py:23: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_ue['media'] = df_ue.mean(axis=1)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20832\1969328386.py:27: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_otan['media'] = df_otan.mean(axis=1)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20832\1969328386.py:32: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %% [markdown]
# <h1>Exercício 2</h1>

# %%
filtro_avancados_ue = df_ue['media'] > media                # Filtrar os países da União Europeia que estão acima da média
df_avancados_ue = df_ue[filtro_avancados_ue]

filtro_avancados_otan = df_otan['media'] > media            # Filtrar os países da OTAN que estão acima da média
df_avancados_otan = df_otan[filtro_avancados_otan]

filtro_avancados_total = df_conjunto['media'] > media       # Juntando os dois filtros
df_avancados_total = df_conjunto[filtro_avancados_total]

# %% [markdown]
# # Exercício 3

# %% [markdown]
# Calculando P(avançado|bloco)

# %%
P_avancado_ue = len(df_avancados_ue) / len(df_ue)           # Probabilidade de ser avançado dado que é da UE
P_avancado_otan = len(df_avancados_otan) / len(df_otan)     # Probabilidade de ser avançado dado que é da OTAN

print(f'Probabilidade de ser avançado dado que é da UE: {P_avancado_ue * 100:.2f}%')
print(f'Probabilidade de ser avançado dado que é da OTAN: {P_avancado_otan * 100:.2f}%')
# Out:
# Probabilidade de ser avançado dado que é da UE: 38.46%
# Probabilidade de ser avançado dado que é da OTAN: 56.52%

# %% [markdown]
# # Exercício 4

# %% [markdown]
# Calculando P(bloco|avançado)

# %%
P_ue = len(df_ue) / len(df_conjunto)
P_otan = len(df_otan) / len(df_conjunto)
P_avancado = len(df_avancados_total) / len(df_conjunto)

#P(A|B) = P(B|A) * P(A) / P(B)

P_ue_avancado = P_avancado_ue * P_ue / P_avancado           # Probabilidade de ser da UE dado que é avançado
P_otan_avancado = P_avancado_otan * P_otan / P_avancado     # Probabilidade de ser da OTAN dado que é avançado

print(f'Probabilidade de ser da UE dado que é avançado: { P_ue_avancado * 100:.2f}%')
print(f'Probabilidade de ser da OTAN dado que é avançado: { P_otan_avancado * 100:.2f}%')
# Out:
# Probabilidade de ser da UE dado que é avançado: 43.48%
# Probabilidade de ser da OTAN dado que é avançado: 56.52%

# %% [markdown]
# # Exercício 5

# %% [markdown]
# Calculando os países não avançados

# %%
# Dataframe com os países não avançados
df_nao_avancados = df_conjunto[~filtro_avancados_total].sort_values(by='media', ascending=False)

# Filtrando os países não avançados da União Europeia
filtro_nao_avancados_ue = df_nao_avancados['Country Name'].isin(paises_eu)
df_nao_avancados_ue = df_nao_avancados[filtro_nao_avancados_ue]

# Filtrando os países não avançados da OTAN
filtro_nao_avancados_otan = df_nao_avancados['Country Name'].isin(paises_otan)
df_nao_avancados_otan = df_nao_avancados[filtro_nao_avancados_otan]

# Juntando os dataframes de países não avançados da União Europeia e da OTAN
filtro_nao_avancados_total = df_nao_avancados['Country Name'].isin(paises_otan) | df_nao_avancados['Country Name'].isin(paises_eu)
df_nao_avancados_total = df_nao_avancados[filtro_nao_avancados_total]

# %%
P_nao_avancado_ue = len(df_nao_avancados_ue) / len(df_ue)           # Probabilidade de não ser avançado, dado que é da UE
P_nao_avancado_otan = len(df_nao_avancados_otan) / len(df_otan)     # Probabilidade de não ser avançado, dado que é da OTAN
P_nao_avancado = len(df_nao_avancados_total) / len(df_conjunto)     # Probabilidade de não ser avançado


P_ue_nao_avancado = P_nao_avancado_ue * P_ue / P_nao_avancado
P_otan_nao_avancado = P_nao_avancado_otan * P_otan / P_nao_avancado

print(f'Probabilidade de ser da União Europeia e não ser avançado: { P_ue_nao_avancado * 100:.2f}%')
print(f'Probabilidade de ser da OTAN e não ser avançado: { P_otan_nao_avancado * 100:.2f}%')
# Out:
# Probabilidade de ser da União Europeia e não ser avançado: 61.54%
# Probabilidade de ser da OTAN e não ser avançado: 38.46%

# %% [markdown]
# Após coletar e analisar os dados calculados anteriormente, foi possível chegar à conclusão que, ao escolher um país avançado, existe uma chance maior de ele pertencer ao bloco da OTAN (56.52%), enquanto que, ao escolher um país não avançado, existe uma chance maior de ele pertencer ao bloco da União Europeia (61.54%).

# %%
def classifica_pais(status):

    # Função criada com base nos dados coletados pelas análises anteriores

    if status == 'avancado':            # Se o país for avançado, ele tende a ser da OTAN (a probabilidade é maior)
        return 'OTAN'

    else:
        return 'UE'                     # Se o país não for avançado, ele tende a ser da União Europeia (a probabilidade é maior)


lista_geral = paises_eu + paises_otan               # Lista com todos os países da União Europeia e da OTAN
dic_geral = {}                                      # Dicionário que futuramente vai armazenar os países e suas classificações


for pais in lista_geral:


    if pais in df_avancados_total['Country Name'].values:       # Se o país estiver no dataframe de países avançados, ele é classificado como avançado
        dic_geral[pais] = 'avancado'

    else:                                                       # Se o país não estiver no dataframe de países avançados, ele é classificado como não avançado
        dic_geral[pais] = 'nao avancado'

    
favoraveis = 0
nao_favoraveis = 0

for pais in lista_geral:

    if classifica_pais(dic_geral[pais]) == 'OTAN':              # Se o país for classificado como OTAN e ele for da OTAN, ele é considerado favorável
        if pais in paises_otan:
            favoraveis += 1
        else:                                                   # Se o país for classificado como OTAN e ele não for da OTAN, ele é considerado não favorável
            nao_favoraveis += 1


    elif classifica_pais(dic_geral[pais]) == 'UE':              # Se o país for classificado como UE e ele for da UE, ele é considerado favorável
        if pais in paises_eu:
            favoraveis += 1
        else:                                                   # Se o país for classificado como UE e ele não for da UE, ele é considerado não favorável
            nao_favoraveis += 1

print(f'Acertos: {favoraveis}')
print(f'Erros: {nao_favoraveis}')
print(f'Acurácia: {favoraveis / (favoraveis + nao_favoraveis) * 100:.2f}%')
# Out:
# Acertos: 30
# Erros: 23
# Acurácia: 56.60%

# %%
plt.figure(figsize=(10, 6))

plt.bar('União Europeia', len(df_avancados_ue), color='#4831D4')                                    # Barra dos avançados da UE
plt.bar('União Europeia', len(df_nao_avancados_ue), bottom=len(df_avancados_ue), color='#F96167')   # Barra dos não avançados da UE
plt.bar('OTAN', len(df_avancados_otan), color='#4831D4')                                            # Barra dos avançados da OTAN
plt.bar('OTAN', len(df_nao_avancados_otan), bottom=len(df_avancados_otan), color='#F96167')         # Barra dos não avançados da OTAN
plt.ylabel('Quantidade de países')
plt.legend(['Avançados', 'Atrasados'])
plt.title('Quantidade de países avançados e atrasados em cada bloco')
plt.show()

# %% [markdown]
# <h1>Exercício 6</h1>

# %% [markdown]
# Após realizar a análise dos resultados obtidos de acordo com o indicador "Gastos do governo com educação (% do PIB)", pudemos concluir que este indicador não é um bom preditor, pois de acordo com a "simulação" realizada pela função criada para definir o bloco econômico de acordo com o estado dele (avançado ou não avançado), obtivemos uma taxa de acertos que pode ser considerada baixa, já que foi de apenas 56.6%, ou seja, durante o processo de simulação foram registrados 30 acertos e 23 erros do sistema. Logo, por mais que a maioria das simulações resultou em acertos, ainda assim a taxa de erros é grande quando comparada com a taxa de acertos.
