# %% [markdown]
# Duvidas
#
# - prints estranhos relacionados a xticks
# - paises com banco de dados completo, gráfico estranho
# - começos diferentes
# - posição legenda

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('dados/API_SE.XPD.TOTL.GD.ZS_DS2_en_csv_v2_4411877/API_SE.XPD.TOTL.GD.ZS_DS2_en_csv_v2_4411877.csv', skiprows=4,decimal='.',encoding='latin')

df_bra = df.iloc[29]   # Dados do Brasil
df_afe = df.iloc[2]    # Dados do Afeganistão
df_nor = df.iloc[177]  # Dados da Noruega

anos = []
for ano in range(2003, 2020,2):
    anos.append(str(ano))

plt.figure(figsize=(12,8))
plt.plot(df_nor[anos],color='green')
plt.plot(df_bra[anos], color='blue')
plt.plot(df_afe[anos], color='red')
plt.legend(['Noruega','Brasil', 'Afeganistão'], loc='best')
plt.title('O quanto alguns países investem de seu PIB em educação', fontsize=20)
plt.xlabel('Anos', fontsize=15)
plt.ylabel('Porcentagem do PIB investida (%)', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(range(1,9,1), fontsize=12)
plt.show()
